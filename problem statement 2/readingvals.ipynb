# %% [markdown]
# # Basal image

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
curve = []
x_3 = []
y_3 = []
plt.style.use('seaborn')
with open("data/IM_0003-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_3.append(float(line.split()[0]))
        y_3.append(float(line.split()[1]))
        curve.append(point)
plt.scatter(x_3, y_3)
plt.plot(x_3, y_3)
plt.plot((x_3[0], x_3[len(x_3)-1]), (y_3[0], y_3[len(y_3)-1]))

        
#x , y = np.loadtext("data/IM_0003_inx.txt", skiprows = 0, unpack = True)
print(y_3)
# Out:
# [85.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85.0, 84.8, 84.8, 84.8, 85.0, 85.2, 85.8, 86.6, 87.6, 88.8, 90.2, 91.0, 92.2, 93.6, 95.0, 96.4, 98.0, 99.4, 101.0, 102.6, 104.2, 105.8, 107.4, 109.0, 110.0, 111.0, 112.2, 113.6, 115.0, 116.0, 116.6, 117.2, 117.8, 118.4, 119.0, 119.2, 119.6, 120.0, 120.0, 120.0, 120.0, 120.0, 120.0, 120.0, 120.0, 119.6, 119.2, 119.0, 118.4, 118.0, 116.6, 115.4, 114.0, 112.8, 111.6, 110.6, 109.6, 108.6, 106.8, 105.8, 104.8, 103.0, 101.4, 100.0, 98.4, 97.0, 95.4, 94.0, 92.6, 91.2, 90.0, 89.0, 88.0, 87.0, 86.0]

# %% [markdown]
# # MID

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
curve = []
x_4 = []
y_4 = []
#plt.style.use('seaborn')
with open("data/IM_0004-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_4.append(float(line.split()[0]))
        y_4.append(float(line.split()[1]))
        curve.append(point)
plt.scatter(x_4, y_4)
plt.plot(x_4, y_4)
plt.plot((x_4[0], x_4[len(x_4)-1]), (y_4[0], y_4[len(y_4)-1]))
        
#x , y = np.loadtext("data/IM_0003_inx.txt", skiprows = 0, unpack = True)
print(y_4)
# Out:
# [102.0, 100.6, 99.2, 98.0, 96.4, 95.0, 93.4, 92.0, 90.2, 88.6, 87.0, 85.6, 84.4, 83.2, 82.0, 81.0, 80.0, 79.4, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.4, 80.0, 80.4, 81.0, 82.2, 83.4, 84.6, 85.8, 87.0, 88.2, 89.6, 91.0, 92.6, 94.2, 96.0, 97.6, 99.2, 101.0, 102.4, 104.0, 105.4, 107.0, 108.0, 109.0, 110.0, 111.0, 111.0, 111.0, 111.0, 111.0, 111.0, 111.0, 110.0, 109.0, 108.0, 106.8, 105.6, 104.4, 103.2]

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
curve = []
x_5 = []
y_5 = []
#plt.style.use('seaborn')
with open("data/IM_0005-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_5.append(float(line.split()[0]))
        y_5.append(float(line.split()[1]))
        curve.append(point)
plt.scatter(x_5, y_5)
plt.plot(x_5, y_5)
plt.plot((x_5[0], x_5[len(x_5)-1]), (y_5[0], y_5[len(y_5)-1]))

        
#x , y = np.loadtext("data/IM_0003_inx.txt", skiprows = 0, unpack = True)
print(y_5)
# Out:
# [94.0, 92.2, 90.6, 89.0, 88.0, 87.0, 85.4, 84.0, 83.0, 82.0, 81.0, 80.4, 80.0, 80.0, 80.0, 80.0, 80.0, 80.6, 81.4, 82.2, 83.0, 84.0, 85.0, 86.0, 87.6, 89.2, 91.0, 92.6, 94.2, 96.0, 97.0, 98.4, 100.0, 101.4, 103.0, 104.6, 106.2, 108.0, 108.2, 108.6, 109.0, 109.0, 109.0, 109.0, 109.0, 108.4, 108.0, 107.0, 106.0, 105.0, 103.6, 102.4, 101.2, 100.0, 98.4, 97.0, 95.4]

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
curve = []
x_8 = []
y_8 = []
plt.style.use('seaborn')
with open("data/IM_0008-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_8.append(float(line.split()[0]))
        y_8.append(float(line.split()[1]))
        curve.append(point)
plt.scatter(x_8, y_8)
plt.plot(x_8, y_8)
plt.plot((x_8[0], x_8[len(x_8)-1]), (y_8[0], y_8[len(y_8)-1]))
        
#x , y = np.loadtext("data/IM_0003_inx.txt", skiprows = 0, unpack = True)
print(y_8)
# Out:
# [67.0, 65.2, 63.4, 61.6, 59.8, 58.0, 56.2, 54.4, 52.6, 51.0, 49.2, 47.4, 45.6, 44.0, 42.4, 41.0, 40.2, 39.6, 39.0, 39.0, 39.0, 39.0, 39.2, 39.6, 40.0, 40.4, 41.0, 41.4, 42.0, 43.0, 44.0, 45.4, 47.0, 48.4, 50.0, 51.6, 53.4, 55.0, 56.8, 58.4, 60.2, 62.0, 63.6, 65.4, 67.0, 68.8, 70.4, 72.2, 74.0, 75.6, 77.4, 79.0, 80.8, 82.4, 84.2, 86.0, 87.8, 89.6, 91.4, 93.4, 95.2, 97.0, 99.0, 100.2, 101.6, 103.0, 104.4, 106.0, 107.2, 108.6, 110.0, 110.4, 111.0, 111.2, 111.4, 111.6, 112.0, 112.0, 111.8, 111.6, 111.4, 111.2, 111.2, 111.0, 110.8, 110.6, 110.6, 110.4, 110.2, 110.0, 110.0, 108.4, 107.0, 106.0, 105.0, 103.0, 101.0, 99.2, 97.2, 95.2, 93.4, 91.4, 89.4, 87.6, 85.6, 83.6, 81.8, 79.8, 78.0, 76.0, 74.2, 72.4, 70.6, 68.8]

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
curve = []
x_13 = []
y_13 = []
plt.style.use('seaborn')
with open("data/IM_0013-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_13.append(float(line.split()[0]))
        y_13.append(float(line.split()[1]))
        curve.append(point)
plt.scatter(x_13, y_13)
plt.plot(x_13, y_13)
plt.plot((x_13[0], x_13[len(x_13)-1]), (y_13[0], y_13[len(y_13)-1]))
        
#x , y = np.loadtext("data/IM_0003_inx.txt", skiprows = 0, unpack = True)
#print(y_13)
